# %%
import polars as pl

# %%
amr = pl.scan_parquet("../temp/data/interim/card_amr.parquet")

# %%
# In AMR data, every column name is antibiotic column except for 'sequence' column
label_columns = [col for col in amr.collect_schema().names() if col != "sequence"] + ["non_amr"]

# %%
print("Label columns:", label_columns)

# %%
# Output the schema as json
pl.Series(label_columns).to_frame("labels").write_csv("../temp/data/cache/labels.csv")
